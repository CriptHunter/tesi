# %%
import pandas as pd
import numpy as np
import pprint

# %%
def get_closest_row(file_path, columns, dt):
    df = pd.read_csv(file_path, header=0)
    df['time'] = pd.to_datetime(df['time'], unit='ms')
    df.sort_values('time', inplace=True)
    df.drop_duplicates(subset='time', keep="first", inplace=True)
    df.set_index('time', inplace=True)
    closest = df.iloc[[df.index.get_loc(dt, method='nearest')]].values[0]
    return np.asarray(closest)

# %%
file_dict = {'activities.csv': ['in_veichle', 'on_bicycle', 'on_foot', 'running', 'still', 'tilting', 'walking', 'unknown'], 
             'audio.csv': ['ringer_mode', 'alarm_volume', 'music_volume', 'notifications_volume', 'ring_volume', 'bt_sco_connected', 'mic_muted', 'music_active', 'speaker_on', 'headset_connected']}

# %%
data_path = 'Datasets/MDF/'
user_dir = data_path + 'user_0'
ignored_apps = 'it.cnr.iit.sensapp com.android.systemui com.sec.android.app.launcher com.android.settings'.split()
print(ignored_apps)

df = pd.read_csv(user_dir + '/running_apps.csv', header=0)
df['time'] = pd.to_datetime(df['time'], unit='ms')
df.sort_values('time', inplace=True)
df.drop_duplicates(subset='time', keep="first", inplace=True)
df.reset_index(drop=True, inplace=True)
df
# Out:
# ['it.cnr.iit.sensapp', 'com.android.systemui', 'com.sec.android.app.launcher', 'com.android.settings']
#                       time                             app            category
# 0  2018-04-24 06:07:19.466              it.cnr.iit.sensapp                 NaN
# 1  2018-04-24 06:12:19.487            com.android.systemui                 NaN
# 2  2018-04-24 06:17:19.502                    com.whatsapp       COMMUNICATION
# 3  2018-04-24 06:22:19.542              it.cnr.iit.sensapp                 NaN
# 4  2018-04-24 06:57:19.368                    com.whatsapp       COMMUNICATION
# 5  2018-04-24 07:07:19.408    com.sec.android.app.launcher     PERSONALIZATION
# 6  2018-04-24 07:12:19.403  com.android.captiveportallogin                 NaN
# 7  2018-04-24 07:42:19.457    com.sec.android.app.launcher     PERSONALIZATION
# 8  2018-04-24 07:57:19.493             com.twitter.android  NEWS_AND_MAGAZINES
# 9  2018-04-24 08:02:19.496    com.sec.android.app.launcher     PERSONALIZATION
# 10 2018-04-24 08:17:19.537                    com.whatsapp       COMMUNICATION
# 11 2018-04-24 08:22:19.555           com.instagram.android              SOCIAL
# 12 2018-04-24 08:37:19.580                    com.whatsapp       COMMUNICATION
# 13 2018-04-24 08:42:19.586                    com.whatsapp       COMMUNICATION
# 14 2018-04-24 08:47:19.602    com.sec.android.app.launcher     PERSONALIZATION

# %%
rows = []
i = 0
for dt in df['time']:
    row = []
    for filename, columns in file_dict.items():
        file_path = user_dir + '/' + filename
        row = row + get_closest_row(file_path, columns, dt).tolist()
    rows.append(row)

df2 = pd.DataFrame(rows, columns=np.concatenate(list(file_dict.values())))
df = pd.concat([df, df2], axis=1)

# %%
df
# Out:
#                       time                             app  \
# 0  2018-04-24 06:07:19.466              it.cnr.iit.sensapp
# 1  2018-04-24 06:12:19.487            com.android.systemui
# 2  2018-04-24 06:17:19.502                    com.whatsapp
# 3  2018-04-24 06:22:19.542              it.cnr.iit.sensapp
# 4  2018-04-24 06:57:19.368                    com.whatsapp
# 5  2018-04-24 07:07:19.408    com.sec.android.app.launcher
# 6  2018-04-24 07:12:19.403  com.android.captiveportallogin
# 7  2018-04-24 07:42:19.457    com.sec.android.app.launcher
# 8  2018-04-24 07:57:19.493             com.twitter.android
# 9  2018-04-24 08:02:19.496    com.sec.android.app.launcher
# 10 2018-04-24 08:17:19.537                    com.whatsapp
# 11 2018-04-24 08:22:19.555           com.instagram.android
# 12 2018-04-24 08:37:19.580                    com.whatsapp
# 13 2018-04-24 08:42:19.586                    com.whatsapp
# 14 2018-04-24 08:47:19.602    com.sec.android.app.launcher
#
#               category  in_veichle  on_bicycle  on_foot  running  still  \
# 0                  NaN           8           9       14        8     23
# 1                  NaN           8           7       35        7      9
# 2        COMMUNICATION          27           8        8        8     11
# 3                  NaN           8           6        6        5     49
# 4        COMMUNICATION           7           8       13        5     39
# 5      PERSONALIZATION           0           0        0        0      0
# 6                  NaN           8           6       27        1     53
# 7      PERSONALIZATION          16          10       10        7     18
# 8   NEWS_AND_MAGAZINES          17           3       31        1     33
# 9      PERSONALIZATION          32           2        8        0     43
# 10       COMMUNICATION           0           0        0        0      0
# 11              SOCIAL           5           4       19        0     66
# 12       COMMUNICATION           0           0        0        0      0
# 13       COMMUNICATION           0           0        0        0      0
# 14     PERSONALIZATION           0           0        0        0      0
#
#     tilting  walking  ...  ringer_mode  alarm_volume  music_volume  \
# 0         0       14  ...            2      0.733333           0.0
# 1         0       35  ...            2      0.733333           0.0
# 2         0        8  ...            1      0.733333           0.0
# 3         0        6  ...            1      0.733333           0.0
# 4         0       13  ...            1      0.733333           0.0
# 5       100        0  ...            1      0.733333           0.0
# 6         0       27  ...            1      0.733333           0.0
# 7         0       10  ...            1      0.733333           0.0
# 8         0       31  ...            1      0.733333           0.0
# 9         0        8  ...            1      0.733333           0.0
# 10      100        0  ...            1      0.733333           0.0
# 11        0       19  ...            1      0.733333           0.0
# 12      100        0  ...            1      0.733333           0.0
# 13      100        0  ...            1      0.733333           0.0
# 14      100        0  ...            1      0.733333           0.0
#
#     notifications_volume  ring_volume  bt_sco_connected  mic_muted  \
# 0                    0.0          1.0             False      False
# 1                    0.0          1.0             False      False
# 2                    0.0          0.0             False      False
# 3                    0.0          0.0             False      False
# 4                    0.0          0.0             False      False
# 5                    0.0          0.0             False      False
# 6                    0.0          0.0             False      False
# 7                    0.0          0.0             False      False
# 8                    0.0          0.0             False      False
# 9                    0.0          0.0             False      False
# 10                   0.0          0.0             False      False
# 11                   0.0          0.0             False      False
# 12                   0.0          0.0             False      False
# 13                   0.0          0.0             False      False
# 14                   0.0          0.0             False      False
#
#     music_active  speaker_on  headset_connected
# 0          False       False              False
# 1          False       False              False
# 2          False       False              False
# 3          False       False              False
# 4          False       False              False
# 5          False       False              False
# 6          False       False              False
# 7          False       False              False
# 8          False       False              False
# 9          False       False              False
# 10         False       False              False
# 11         False       False              False
# 12         False       False              False
# 13         False       False              False
# 14         False       False              False
#
# [15 rows x 21 columns]
